# %%
# %run lac-gac-works-with-new-lac-correct-lac-area_SCFV_40_pixels.py
# Out:
# 19920101-ESACCI-L3C_SNOW-SCFV-AVHRR_NOAA11-fv4.0.nc Region: usa_Alaska
#
# usa_Alaska
# After GAC crop:
# lat: 66.17500305175781 68.125
# lon: -153.3249969482422 -151.375
# SCFV: nan nan
# [nan]
# usa_Alaska nan  <-- GAC VALUE
# 19920101-ESACCI-L3C_SNOW-SCFV-AVHRR_NOAA11-fv4.0.nc Region: can_Auyuittuq
#
# can_Auyuittuq
# After GAC crop:
# lat: 67.5250015258789 69.4749984741211
# lon: -64.9749984741211 -63.025001525878906
# SCFV: nan nan
# [nan]
# can_Auyuittuq nan  <-- GAC VALUE
# 19920101-ESACCI-L3C_SNOW-SCFV-AVHRR_NOAA11-fv4.0.nc Region: chl_Rafael
#
# chl_Rafael
# After GAC crop:
# lat: -46.724998474121094 -44.775001525878906
# lon: -72.9749984741211 -71.0250015258789
# SCFV: 0.0 0.0
# [ 0. nan]
# chl_Rafael 0.0  <-- GAC VALUE
# 19920101-ESACCI-L3C_SNOW-SCFV-AVHRR_NOAA11-fv4.0.nc Region: nor_Jotunheim
#
# nor_Jotunheim
# After GAC crop:
# lat: 61.724998474121094 63.67499923706055
# lon: 7.074999809265137 9.024999618530273
# SCFV: 0.0 100.0
# [  0.  55.  58.  64. 100.  nan]
# ...
