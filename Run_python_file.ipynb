# %% [markdown]
# Read the contents of the file

# %%
with open("example.py") as f:
    print(f.read())
# Out:
# print("testi")

# %% [markdown]
# Run the contents of the file

# %%
# %run ./example.py
# Out:
# testi
