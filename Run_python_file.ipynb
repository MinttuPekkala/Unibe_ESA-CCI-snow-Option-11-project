# %%
# %run ./lac-gac.py
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File ~\Documents\GitHub\Unibe_ESA CCI snow Option 11 project\lac-gac.py:353
#     350 timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
#     351 # Get GAC template file for interpolation of LAC files
#     352 gac_templ = load_data(
# --> 353     [v for scenes_dictionary in selected_scenes.values() for v in scenes_dictionary.get('gac', {}).values()][0][0])
#     354 scene_counter = 0
#     355 # Iterate through the original dictionary
#
# IndexError: list index out of range
