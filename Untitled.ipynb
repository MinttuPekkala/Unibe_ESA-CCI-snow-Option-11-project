# %%
import pysftp
# Out:
# C:\Users\minttu\anaconda3\envs\esa-snow\Lib\site-packages\paramiko\pkey.py:82: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "cipher": algorithms.TripleDES,
# C:\Users\minttu\anaconda3\envs\esa-snow\Lib\site-packages\paramiko\transport.py:253: CryptographyDeprecationWarning: TripleDES has been moved to cryptography.hazmat.decrepit.ciphers.algorithms.TripleDES and will be removed from cryptography.hazmat.primitives.ciphers.algorithms in 48.0.0.
#   "class": algorithms.TripleDES,

# %%
cnopts = pysftp.CnOpts()
cnopts.hostkeys = None  # disable host key checking (or use known_hosts)

with pysftp.Connection(
    host='mpekkala@rsgb-509b.giub.unibe.ch',
    username='mpekkala',
    password='Herttalumesa1998+',
    cnopts=cnopts
) as sftp:
    print("Connected!")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\envs\esa-snow\Lib\site-packages\pysftp\__init__.py:176, in Connection._start_transport(self, host, port)
#     175 try:
# --> 176     self._transport = paramiko.Transport((host, port))
#     177     # Set security ciphers if set
#
# File ~\anaconda3\envs\esa-snow\Lib\site-packages\paramiko\transport.py:426, in Transport.__init__(self, sock, default_window_size, default_max_packet_size, gss_kex, gss_deleg_creds, disabled_algorithms, server_sig_algs)
#     425 reason = "No suitable address family"
# --> 426 addrinfos = socket.getaddrinfo(
#     427     hostname, port, socket.AF_UNSPEC, socket.SOCK_STREAM
#     428 )
#     429 for family, socktype, proto, canonname, sockaddr in addrinfos:
#
# File ~\anaconda3\envs\esa-snow\Lib\socket.py:963, in getaddrinfo(host, port, family, type, proto, flags)
# ...

# %%
cnopts = pysftp.CnOpts()
cnopts.hostkeys = None

with pysftp.Connection(
    host='rsgb-509b.giub.unibe.ch',      
    username='mpekkala',                   
    password='Herttalumesa1998+',
    cnopts=cnopts
) as sftp:
    print("Connected!")
# Out:
# ---------------------------------------------------------------------------
# AuthenticationException                   Traceback (most recent call last)
# Cell In[6], line 4
#       1 cnopts = pysftp.CnOpts()
#       2 cnopts.hostkeys = None
# ----> 4 with pysftp.Connection(
#       5     host='rsgb-509b.giub.unibe.ch',
#       6     username='mpekkala',
#       7     password='Herttalumesa1998+',
#       8     cnopts=cnopts
#       9 ) as sftp:
#      10     print("Connected!")
#
# File ~\anaconda3\envs\esa-snow\Lib\site-packages\pysftp\__init__.py:143, in Connection.__init__(self, host, username, private_key, password, port, private_key_pass, ciphers, log, cnopts, default_path)
#     141 self._transport.use_compression(self._cnopts.compression)
#     142 self._set_authentication(password, private_key, private_key_pass)
# --> 143 self._transport.connect(**self._tconnect)
#
# ...

# %%
with pysftp.Connection(
    host='rsgb-509b.giub.unibe.ch',
    username='mpekkala',
    private_key='C:/Users/minttu/.ssh/id_rsa',  # your private key path
    cnopts=cnopts
) as sftp:
    print("Connected!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 with pysftp.Connection(
#       2     host='rsgb-509b.giub.unibe.ch',
#       3     username='mpekkala',
#       4     private_key='C:/Users/minttu/.ssh/id_rsa',  # your private key path
#       5     cnopts=cnopts
#       6 ) as sftp:
#       7     print("Connected!")
#
# File ~\anaconda3\envs\esa-snow\Lib\site-packages\pysftp\__init__.py:142, in Connection.__init__(self, host, username, private_key, password, port, private_key_pass, ciphers, log, cnopts, default_path)
#     140 self._start_transport(host, port)
#     141 self._transport.use_compression(self._cnopts.compression)
# --> 142 self._set_authentication(password, private_key, private_key_pass)
#     143 self._transport.connect(**self._tconnect)
#
# ...
